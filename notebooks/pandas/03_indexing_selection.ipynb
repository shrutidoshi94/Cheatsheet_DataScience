# %% [markdown]
# # 03 Indexing Selection
# Welcome to the Pandas syntax exploration notebook. Here you can run code corresponding to the flip cards.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(f'Ready to explore {lib}!')
